# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
ur = pd.read_csv('ncr_ride_bookings.csv')
print(ur)
# Out:
#               Date      Time    Booking ID   Booking Status   Customer ID  \
# 0       2024-03-23  12:29:38  "CNR5884300"  No Driver Found  "CID1982111"
# 1       2024-11-29  18:01:39  "CNR1326809"       Incomplete  "CID4604802"
# 2       2024-08-23  08:56:10  "CNR8494506"        Completed  "CID9202816"
# 3       2024-10-21  17:17:25  "CNR8906825"        Completed  "CID2610914"
# 4       2024-09-16  22:08:00  "CNR1950162"        Completed  "CID9933542"
# ...            ...       ...           ...              ...           ...
# 149995  2024-11-11  19:34:01  "CNR6500631"        Completed  "CID4337371"
# 149996  2024-11-24  15:55:09  "CNR2468611"        Completed  "CID2325623"
# 149997  2024-09-18  10:55:15  "CNR6358306"        Completed  "CID9925486"
# 149998  2024-10-05  07:53:34  "CNR3030099"        Completed  "CID9415487"
# 149999  2024-03-10  15:38:03  "CNR3447390"        Completed  "CID4108667"
#
#          Vehicle Type         Pickup Location      Drop Location  Avg VTAT  \
# ...

# %%
print(ur.head(7))
# Out:
#          Date      Time    Booking ID   Booking Status   Customer ID  \
# 0  2024-03-23  12:29:38  "CNR5884300"  No Driver Found  "CID1982111"
# 1  2024-11-29  18:01:39  "CNR1326809"       Incomplete  "CID4604802"
# 2  2024-08-23  08:56:10  "CNR8494506"        Completed  "CID9202816"
# 3  2024-10-21  17:17:25  "CNR8906825"        Completed  "CID2610914"
# 4  2024-09-16  22:08:00  "CNR1950162"        Completed  "CID9933542"
# 5  2024-02-06  09:44:56  "CNR4096693"        Completed  "CID4670564"
# 6  2024-06-17  15:45:58  "CNR2002539"        Completed  "CID6800553"
#
#     Vehicle Type      Pickup Location      Drop Location  Avg VTAT  Avg CTAT  \
# 0          eBike          Palam Vihar            Jhilmil       NaN       NaN
# 1       Go Sedan        Shastri Nagar  Gurgaon Sector 56       4.9      14.0
# 2           Auto              Khandsa      Malviya Nagar      13.4      25.8
# 3  Premier Sedan  Central Secretariat           Inderlok      13.1      28.5
# ...

# %%
print(ur.tail(5))
# Out:
#               Date      Time    Booking ID Booking Status   Customer ID  \
# 149995  2024-11-11  19:34:01  "CNR6500631"      Completed  "CID4337371"
# 149996  2024-11-24  15:55:09  "CNR2468611"      Completed  "CID2325623"
# 149997  2024-09-18  10:55:15  "CNR6358306"      Completed  "CID9925486"
# 149998  2024-10-05  07:53:34  "CNR3030099"      Completed  "CID9415487"
# 149999  2024-03-10  15:38:03  "CNR3447390"      Completed  "CID4108667"
#
#          Vehicle Type         Pickup Location      Drop Location  Avg VTAT  \
# 149995        Go Mini                 MG Road           Ghitorni      10.2
# 149996        Go Mini        Golf Course Road         Akshardham       5.1
# 149997       Go Sedan  Satguru Ram Singh Marg           Jor Bagh       2.7
# 149998           Auto               Ghaziabad         Saidulajab       6.9
# 149999  Premier Sedan         Ashok Park Main  Gurgaon Sector 29       3.5
#
#         Avg CTAT  ...  Reason for cancelling by Customer  \
# ...

# %%
print(ur.shape)
# Out:
# (150000, 21)

# %%
print(ur.columns)
# Out:
# Index(['Date', 'Time', 'Booking ID', 'Booking Status', 'Customer ID',
#        'Vehicle Type', 'Pickup Location', 'Drop Location', 'Avg VTAT',
#        'Avg CTAT', 'Cancelled Rides by Customer',
#        'Reason for cancelling by Customer', 'Cancelled Rides by Driver',
#        'Driver Cancellation Reason', 'Incomplete Rides',
#        'Incomplete Rides Reason', 'Booking Value', 'Ride Distance',
#        'Driver Ratings', 'Customer Rating', 'Payment Method'],
#       dtype='object')

# %%
print(ur.isnull().sum())
# Out:
# Date                                      0
# Time                                      0
# Booking ID                                0
# Booking Status                            0
# Customer ID                               0
# Vehicle Type                              0
# Pickup Location                           0
# Drop Location                             0
# Avg VTAT                              10500
# Avg CTAT                              48000
# Cancelled Rides by Customer          139500
# Reason for cancelling by Customer    139500
# Cancelled Rides by Driver            123000
# Driver Cancellation Reason           123000
# Incomplete Rides                     141000
# Incomplete Rides Reason              141000
# Booking Value                         48000
# Ride Distance                         48000
# Driver Ratings                        57000
# Customer Rating                       57000
# Payment Method                        48000
# dtype: int64

# %%
print(ur['Reason for cancelling by Customer'].unique())
# Out:
# [nan 'Driver is not moving towards pickup location'
#  'Driver asked to cancel' 'AC is not working' 'Change of plans'
#  'Wrong Address']

# %%
print(ur['Avg VTAT'].unique())
# Out:
# [ nan  4.9 13.4 13.1  5.3  5.1  7.1 12.1  6.1  7.7  4.6 12.2 14.   8.5
#   5.6  6.  12.4 10.3  7.  10.4  7.9 13.6 11.5  3.1  8.9  9.2  2.   5.4
#  14.6  6.7  6.6 10.  11.   8.  12.8  6.4 11.3  2.3  7.8  8.8  9.9  4.1
#  11.2  3.   9.1  4.3 11.4  6.3 11.7 16.6  5.8  4.   3.4 11.1  5.9  8.1
#   5.  12.   3.2  9.6  3.9  8.4 10.9  5.7  8.6  9.5  2.6  2.1 14.4  7.5
#  10.8 14.7  3.5  8.3 11.9 12.5 13.3  9.7  3.6  9.4  9.   2.4 19.1  2.9
#  18.5 16.1 13.7  4.5  6.9  6.2  7.2  3.7 11.6  3.3  4.7  7.4  9.3  8.2
#  13.5  4.4  2.7  7.3 10.5  6.8 10.7 12.3  3.8 10.2  9.8  8.7 14.2  6.5
#  12.9  4.2  5.2 16.9  7.6 14.9 11.8 14.3 10.1 12.6 14.8 13.2 14.5  4.8
#  14.1  2.5 15.  16.2 12.7  5.5  2.8 19.2 18.  13.9 13.  10.6 20.  17.6
#  15.7  2.2 16.5 15.9 19.6 19.9 19.8 16.  16.4 13.8 18.7 17.  15.5 16.8
#  16.7 15.4 18.8 17.8 19.3 17.2 15.2 19.7 17.5 17.1 16.3 15.1 18.3 17.3
#  19.4 19.5 17.4 19.  18.6 15.6 18.2 18.4 18.1 15.3 17.9 17.7 18.9 15.8]

# %%
a = ur['Avg VTAT'].median()
print(ur['Avg VTAT'].fillna(a,inplace=True))
# Out:
# None
# C:\Users\abdul\AppData\Local\Temp\ipykernel_19224\3157878075.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   print(ur['Avg VTAT'].fillna(a,inplace=True))

# %%
print(ur['Avg VTAT'].isnull().sum())
# Out:
# 0

# %%
print(ur['Avg CTAT'].isnull().sum())
print(ur['Avg CTAT'].unique())
# Out:
# 48000
# [ nan 14.  25.8 28.5 19.6 18.1 20.4 16.5 26.  18.9 28.2 30.9 36.9 27.5
#  33.7 21.3 25.1 41.1 25.2 20.7 31.1 41.  20.5 19.4 25.4 30.  35.8 18.7
#  10.5 42.3 29.7 42.2 21.6 40.7 35.4 23.2 42.1 21.5 33.  10.1 24.3 44.5
#  27.1 38.5 17.2 37.3 26.7 34.7 39.1 23.  31.3 43.7 35.  15.6 43.6 18.
#  32.7 24.6 38.9 16.4 36.2 35.5 41.7 38.  40.  37.  40.4 28.7 30.6 21.1
#  18.8 30.4 15.9 21.9 25.  44.4 16.7 26.3 15.8 31.5 30.7 23.6 24.2 17.9
#  15.5 25.3 37.4 22.8 28.9 44.7 24.8 26.6 32.6 24.4 39.3 32.5 43.1 26.5
#  17.  20.6 37.7 40.2 31.6 33.5 32.9 17.7 39.  18.4 41.8 22.  10.3 15.7
#  16.8 22.2 33.1 27.9 34.1 33.9 22.4 34.6 20.2 30.8 20.  43.4 27.2 30.5
#  27.4 28.1 31.4 15.3 39.9 37.9 37.8 40.6 23.7 31.9 19.7 23.1 20.9 25.5
#  42.5 29.8 42.6 41.6 34.9 23.4 17.3 41.2 27.3 20.1 18.5 36.4 12.4 35.7
#  27.7 33.6 26.2 26.4 19.2 21.  36.8 31.7 33.8 19.8 18.2 28.4 44.8 39.6
#  39.8 42.4 29.  24.  18.3 34.8 16.  22.6 30.1 44.  17.6 29.1 15.4 19.1
# ...

# %%
b = ur['Avg CTAT'].median()
print(ur['Avg CTAT'].fillna(b,inplace=True))
# Out:
# None
# C:\Users\abdul\AppData\Local\Temp\ipykernel_19224\3469659853.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   print(ur['Avg CTAT'].fillna(b,inplace=True))

# %%
print(ur['Avg CTAT'].isnull().sum())
# Out:
# 0

# %%
print(ur[ur['Cancelled Rides by Customer']==1]['Cancelled Rides by Customer'])
# Out:
# 18        1.0
# 39        1.0
# 46        1.0
# 62        1.0
# 78        1.0
#          ...
# 149943    1.0
# 149952    1.0
# 149956    1.0
# 149963    1.0
# 149965    1.0
# Name: Cancelled Rides by Customer, Length: 10500, dtype: float64

# %%
print(ur['Cancelled Rides by Customer'].fillna(0,inplace=True))
# Out:
# C:\Users\abdul\AppData\Local\Temp\ipykernel_19224\3577527006.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   print(ur['Cancelled Rides by Customer'].fillna(0,inplace=True))
# None

# %%
print(ur['Cancelled Rides by Customer'].unique())
# Out:
# [0. 1.]

# %%
print(ur.isnull().sum())
# Out:
# Date                                      0
# Time                                      0
# Booking ID                                0
# Booking Status                            0
# Customer ID                               0
# Vehicle Type                              0
# Pickup Location                           0
# Drop Location                             0
# Avg VTAT                                  0
# Avg CTAT                                  0
# Cancelled Rides by Customer               0
# Reason for cancelling by Customer    139500
# Cancelled Rides by Driver            123000
# Driver Cancellation Reason           123000
# Incomplete Rides                     141000
# Incomplete Rides Reason              141000
# Booking Value                         48000
# Ride Distance                         48000
# Driver Ratings                        57000
# Customer Rating                       57000
# Payment Method                        48000
# dtype: int64

# %%
print(ur['Cancelled Rides by Driver'].unique())
# Out:
# [nan  1.]

# %%
print(ur['Cancelled Rides by Driver'].fillna(0,inplace=True))
# Out:
# None
# C:\Users\abdul\AppData\Local\Temp\ipykernel_19224\2022270796.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   print(ur['Cancelled Rides by Driver'].fillna(0,inplace=True))

# %%
print(ur['Incomplete Rides'].unique())
# Out:
# [nan  1.]

# %%
print(ur['Incomplete Rides'].fillna(0,inplace=True))
# Out:
# None
# C:\Users\abdul\AppData\Local\Temp\ipykernel_19224\258628998.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   print(ur['Incomplete Rides'].fillna(0,inplace=True))

# %%
print(ur.isnull().sum())
# Out:
# Date                                      0
# Time                                      0
# Booking ID                                0
# Booking Status                            0
# Customer ID                               0
# Vehicle Type                              0
# Pickup Location                           0
# Drop Location                             0
# Avg VTAT                                  0
# Avg CTAT                                  0
# Cancelled Rides by Customer               0
# Reason for cancelling by Customer    139500
# Cancelled Rides by Driver                 0
# Driver Cancellation Reason           123000
# Incomplete Rides                          0
# Incomplete Rides Reason              141000
# Booking Value                         48000
# Ride Distance                         48000
# Driver Ratings                        57000
# Customer Rating                       57000
# Payment Method                        48000
# dtype: int64

# %%
print(ur['Booking Value'].isnull().sum())
print(ur['Booking Value'].unique())
# Out:
# 48000
# [  nan  237.  627. ... 3161. 2842. 3028.]

# %%
c = ur['Booking Value'].median()
print(ur['Booking Value'].fillna(c,inplace=True))
# Out:
# None
# C:\Users\abdul\AppData\Local\Temp\ipykernel_19224\826661946.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   print(ur['Booking Value'].fillna(c,inplace=True))

# %%
print(ur[['Ride Distance','Driver Ratings','Customer Rating','Payment Method']].isnull().sum())
# Out:
# Ride Distance      48000
# Driver Ratings     57000
# Customer Rating    57000
# Payment Method     48000
# dtype: int64

# %%
d = ur['Ride Distance'].median()
print(ur['Ride Distance'].fillna(d,inplace=True))
# Out:
# None
# C:\Users\abdul\AppData\Local\Temp\ipykernel_19224\2827839897.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   print(ur['Ride Distance'].fillna(d,inplace=True))

# %%
e = ur['Driver Ratings'].median()
print(ur['Driver Ratings'].fillna(e,inplace=True))
# Out:
# None
# C:\Users\abdul\AppData\Local\Temp\ipykernel_19224\4224897415.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   print(ur['Driver Ratings'].fillna(e,inplace=True))

# %%
f = ur['Customer Rating'].median()
print(ur['Customer Rating'].fillna(f,inplace=True))
# Out:
# None
# C:\Users\abdul\AppData\Local\Temp\ipykernel_19224\4028743705.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   print(ur['Customer Rating'].fillna(f,inplace=True))

# %%
print(ur['Payment Method'].fillna(method='ffill',inplace=True))
# Out:
# None
# C:\Users\abdul\AppData\Local\Temp\ipykernel_19224\3565609314.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   print(ur['Payment Method'].fillna(method='ffill',inplace=True))
# C:\Users\abdul\AppData\Local\Temp\ipykernel_19224\3565609314.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   print(ur['Payment Method'].fillna(method='ffill',inplace=True))

# %%
print(ur['Payment Method'].isnull().sum())
# Out:
# 1

# %%
print(ur.isnull().sum())
# Out:
# Date                                      0
# Time                                      0
# Booking ID                                0
# Booking Status                            0
# Customer ID                               0
# Vehicle Type                              0
# Pickup Location                           0
# Drop Location                             0
# Avg VTAT                                  0
# Avg CTAT                                  0
# Cancelled Rides by Customer               0
# Reason for cancelling by Customer    139500
# Cancelled Rides by Driver                 0
# Driver Cancellation Reason           123000
# Incomplete Rides                          0
# Incomplete Rides Reason              141000
# Booking Value                             0
# Ride Distance                             0
# Driver Ratings                            0
# Customer Rating                           0
# Payment Method                            1
# dtype: int64

# %%
print(ur.drop(['Reason for cancelling by Customer','Driver Cancellation Reason','Incomplete Rides Reason'],axis=1,inplace=True))
# Out:
# None

# %%
print(ur.isnull().sum())
# Out:
# Date                           0
# Time                           0
# Booking ID                     0
# Booking Status                 0
# Customer ID                    0
# Vehicle Type                   0
# Pickup Location                0
# Drop Location                  0
# Avg VTAT                       0
# Avg CTAT                       0
# Cancelled Rides by Customer    0
# Cancelled Rides by Driver      0
# Incomplete Rides               0
# Booking Value                  0
# Ride Distance                  0
# Driver Ratings                 0
# Customer Rating                0
# Payment Method                 1
# dtype: int64

# %%
print(ur['Payment Method'].fillna(method='bfill',inplace=True))
# Out:
# None
# C:\Users\abdul\AppData\Local\Temp\ipykernel_19224\2946482744.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   print(ur['Payment Method'].fillna(method='bfill',inplace=True))
# C:\Users\abdul\AppData\Local\Temp\ipykernel_19224\2946482744.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   print(ur['Payment Method'].fillna(method='bfill',inplace=True))

# %%
print(ur.isnull().sum())
# Out:
# Date                           0
# Time                           0
# Booking ID                     0
# Booking Status                 0
# Customer ID                    0
# Vehicle Type                   0
# Pickup Location                0
# Drop Location                  0
# Avg VTAT                       0
# Avg CTAT                       0
# Cancelled Rides by Customer    0
# Cancelled Rides by Driver      0
# Incomplete Rides               0
# Booking Value                  0
# Ride Distance                  0
# Driver Ratings                 0
# Customer Rating                0
# Payment Method                 0
# dtype: int64

# %%
ur.to_csv(
    r"C:\Users\abdul\Downloads\uber_cleaned_ready1.csv",
    index=False,
    encoding="utf-8"
)
